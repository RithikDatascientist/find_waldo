# %%
from ultralytics import YOLO

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="B01sopzLryWU1hOTbIBM")
project = rf.workspace("waldo-0jhbv").project("waldo-ghwru")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"Number of GPUs: {torch.cuda.device_count()}")
# Out:
# CUDA available: True
# Number of GPUs: 1

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLO11n model
model = YOLO("yolov8n.pt")

# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data=r"C:\works\find_waldo\waldo-5\data.yaml", epochs=100, imgsz=640, batch = 15,device=0)
# Out:
# Ultralytics 8.3.119  Python-3.10.16 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# ...

# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO(r"c:\works\runs\detect\train10\weights\best.pt")

# Run inference on a new image
results = model.predict(source=r"C:/works/find_waldo/waldo-5/test/images/28_jpg.rf.4486cfbb25ca1a6e18f524e972f6cc20.jpg", show=True, save=True)
# Out:
# WARNING Environment does not support cv2.imshow() or PIL Image.show()
# OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1301: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'
#
#
# image 1/1 C:\works\find_waldo\waldo-5\test\images\28_jpg.rf.4486cfbb25ca1a6e18f524e972f6cc20.jpg: 640x384 1 waldorotation, 76.0ms
# Speed: 5.2ms preprocess, 76.0ms inference, 143.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to c:\works\runs\detect\predict10
